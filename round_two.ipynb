# %%
import pandas as pd
df = pd.read_excel('GPTW.xlsx')

# %%
df
# Out:
#     Restricted Information - Not for Further Distribution  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3            Global filter (Nov 2023): Overall Results
# 4                                                  NaN
# ..                                                 ...
# 416                                                NaN
# 417                                                NaN
# 418                                                NaN
# 419                                                NaN
# 420                                                NaN
#
#                                             Unnamed: 1           Unnamed: 2  \
# 0                                                  NaN                  NaN
# 1    HUGO BOSS AG\nGPTW Survey 2023\nOctober 30, 20...  Overall\n(Nov 2023)
# ...

# %%
main_categories = df.iloc[1].dropna()[2:]
main_categories[]
# Out:
# Unnamed: 9                              Company Code
# Unnamed: 54             Confidence in Executive Team
# Unnamed: 59                              Corp/Retail
# Unnamed: 62                              cost center
# Unnamed: 896                          cost center ID
# Unnamed: 1769                                Country
# Unnamed: 1803                        Functional Area
# Unnamed: 1829                                 Gender
# Unnamed: 1833                               Grouping
# Unnamed: 1987                                    Hub
# Unnamed: 1999                       Managerial Level
# Unnamed: 2004    Meaningful Innovation Opportunities
# Unnamed: 2010                    Organizational Unit
# Unnamed: 3053                    Pers. Sub Area Text
# Unnamed: 3572               Reporting Structure Area
# Unnamed: 3645                                Site ID
# Unnamed: 4112                            Subgrouping
# Unnamed: 4380                              Subsidary
# ...

# %%
headers = df.iloc[2]
headers
# Out:
# Restricted Information - Not for Further Distribution                     NaN
# Unnamed: 1                                                                NaN
# Unnamed: 2                                                                NaN
# Unnamed: 3                                                25 years or younger
# Unnamed: 4                                               26 years to 34 years
#                                                                  ...
# Unnamed: 4428                                            16 years to 20 years
# Unnamed: 4429                                                   Over 20 years
# Unnamed: 4430                                                             NaN
# Unnamed: 4431                                                       Full-time
# Unnamed: 4432                                                       Part-time
# Name: 2, Length: 4433, dtype: object

# %%
camaraderie_rows = df.iloc[226:233]
camaraderie_rows
# Out:
#     Restricted Information - Not for Further Distribution  \
# 226                                        Camaraderie
# 227                                                NaN
# 228                                                NaN
# 229                                                NaN
# 230                                                NaN
# 231                                                NaN
# 232                                                NaN
#
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 226  When you join the company, you are made to fee...         85         84
# 227       People celebrate special events around here.         79         79
# 228                       I can be myself around here.         78         79
# 229                       This is a fun place to work.         73         71
# 230  When people change jobs or work units, they ar...         71         67
# ...
